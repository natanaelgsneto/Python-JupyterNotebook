# %% [markdown]
# # <font color='blue'>Data Science Academy</font>
#
# ## <font color='blue'>Fundamentos de Linguagem Python Para Análise de Dados e Data Science</font>
#
# ## <font color='blue'>Visualização de Dados com Seaborn</font>

# %% [markdown]
# ![DSA](imagens/dsa_cap11.png)

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.9.13

# %% [markdown]
# ## Statistical Data Visualization com Seaborn

# %% [markdown]
# https://seaborn.pydata.org/

# %%
# !pip install -q seaborn==0.12.2

# %%
# Imports
import random
import numpy as np
import pandas as pd
import matplotlib as mat
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
np.__version__
# Out:
# '1.21.5'

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
mat.__version__
# Out:
# '3.5.2'

# %%
import seaborn as sea
sea.__version__
# Out:
# '0.12.2'

# %% [markdown]
# ## Criando Gráficos com Seaborn

# %%
# Carregando um dos datasets que vem com o Seaborn
dados = sea.load_dataset("tips")

# %%
dados.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# O método joinplot cria plot de 2 variáveis com gráficos bivariados e univariados
sea.jointplot(data = dados, x = "total_bill", y = "tip", kind = 'reg')

# %%
# O método lmplot() cria plot com dados e modelos de regressão entre a variável fumante (smoker), valor total da conta(total_bill) e gorjeta(tip)
sea.lmplot(data = dados, x = "total_bill", y = "tip", col = "smoker")

# %%
# Construindo um dataframe com Pandas
df = pd.DataFrame()

# %%
# Alimentando o Dataframe com valores aleatórios
df['idade'] = random.sample(range(20, 100), 30)
df['peso'] = random.sample(range(55, 150), 30)

# %%
df.shape  #30 linhas e duas colunas
# Out:
# (30, 2)

# %%
df.head()
# Out:
#    idade  peso
# 0     93   112
# 1     75   131
# 2     80    98
# 3     28    95
# 4     89   129

# %%
# lmplot
sea.lmplot(data = df, x = "idade", y = "peso", fit_reg = True)
#nessa correlação negativa, quanto maior o peso, menor a idade 
# se a linha estivesse no meio a correlação era neutra

# %%
# kdeplot
sea.kdeplot(df.idade) #a maioria das pessoas tem  idade de 60 anos
# Out:
# <AxesSubplot:xlabel='idade', ylabel='Density'>

# %%
# kdeplot
sea.kdeplot(df.peso)
# Out:
# <AxesSubplot:xlabel='peso', ylabel='Density'>

# %%
# distplot
sea.distplot(df.peso) # a maioria estão com o peso entre 120 e 125 kg
# Out:
# <AxesSubplot:xlabel='peso', ylabel='Density'>

# %%
# Histograma
plt.hist(df.idade, alpha = .3)
sea.rugplot(df.idade) # o rugplot cria-se os tracinho em laranja
# Out:
# <AxesSubplot:xlabel='idade'>

# %%
# Box Plot
sea.boxplot(df.idade, color = 'm') 
#a linha do meio que está entre 60 e 70 é a mediana,
#a  linha que está em 52  é o primeiro quartil e a que está
#entre 79 e 80 é o terceiro quartil
# Out:
# <AxesSubplot:>

# %%
# Box Plot
sea.boxplot(df.peso, color = 'y')
# Out:
# <AxesSubplot:>

# %%
# Violin Plot
sea.violinplot(df.idade, color = 'g')
# Out:
# <AxesSubplot:>

# %%
# Violin Plot
sea.violinplot(df.peso, color = 'cyan')
# Out:
# <AxesSubplot:>

# %%
# Clustermap
sea.clustermap(df)

# %% [markdown]
# ## Usando Matplotlib, Seaborn, NumPy e Pandas na Criação de Gráfico Estatístico

# %%
# Valores randômicos
np.random.seed(42)
n = 1000
pct_smokers = 0.2

# Variáveis
flag_fumante = np.random.rand(n) < pct_smokers
idade = np.random.normal(40, 10, n)
altura = np.random.normal(170, 10, n)
peso = np.random.normal(70, 10, n)

# Dataframe
dados = pd.DataFrame({'altura': altura, 'peso': peso, 'flag_fumante': flag_fumante})

# Cria os dados para a variável flag_fumante
dados['flag_fumante'] = dados['flag_fumante'].map({True: 'Fumante', False: 'Não Fumante'})

# %%
dados.shape
# Out:
# (1000, 3)

# %%
dados.head()
# Out:
#        altura       peso flag_fumante
# 0  155.936825  78.745171  Não Fumante
# 1  169.168944  63.502348  Não Fumante
# 2  154.952796  57.967991  Não Fumante
# 3  177.600560  59.579556  Não Fumante
# 4  170.824398  65.127971      Fumante

# %%
# Style
sea.set(style = "ticks")

# lmplot
sea.lmplot(x = 'altura', 
           y = 'peso', 
           data = dados, 
           hue = 'flag_fumante', #hue preenche o conteúdo do dado
           palette = ['tab:blue', 'tab:orange'], 
           height = 7)

# Labels e título
plt.xlabel('Altura (cm)')
plt.ylabel('Peso (kg)')
plt.title('Relação Entre Altura e Peso de Fumantes e Não Fumantes')

# Remove as bordas
sea.despine()

# Show
plt.show()

# %%
#No gráfico acima não há relação entre as pessoas que não fumam (Não fumante) 
#enquanto para os fumantes há uma relação positiva entre o peso e a altura

# %% [markdown]
# Conheça a Formação Análise Estatística. Os alunos aprendem a construir diversos gráficos para análise estatística em Linguagem R e Linguagem Python. Confira:
#
# https://www.datascienceacademy.com.br/bundle/formacao-analise-estatistica

# %% [markdown]
# # Fim

# %% [markdown]
# ### Obrigado
#
# ### Visite o Blog da Data Science Academy - <a href="http://blog.dsacademy.com.br">Blog DSA</a>
